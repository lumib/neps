# %%
import nosbench
from nosbench.program import Program, Instruction, Pointer
from nosbench.function import Function, interpolate, bias_correct, clip, size
import torch

import pprint

from neps.space.new_space import space
from neps.space.new_space import config_string

EPOCHS_PER_CONFIG = 1
AVAILABLE_VARIABLE_SLOTS = 11 # As per the NOSBench paper

# %%
def _function_writer(operation: callable, *args, store: int) -> tuple[Function, list[Pointer], Pointer]:
    return Function(operation, len(args)), [Pointer(var) if isinstance(var, int) else Pointer(var()) for var in args], store
    
def program_compiler(instruction: tuple[callable, list[Pointer], Pointer], *args) -> Program:
    if len(args) == 0:
        return Program([Instruction(instruction[0], inputs=instruction[1], output=instruction[2])])
    else:
        return Program(program_compiler(instruction) + sum(args,[]))

class nosBench(space.Pipeline):
    _UNARY_FUN = space.Categorical(
        choices=(torch.square, torch.exp, torch.log, torch.sign, torch.sqrt, torch.abs, torch.norm, torch.sin, torch.cos, torch.tan, torch.asin, torch.acos, torch.atan, torch.mean, torch.std, size,)
    )

    _BINARY_FUN = space.Categorical(
        choices=(clip, torch.div, torch.mul, torch.add, torch.sub, torch.minimum, torch.maximum, torch.heaviside)
    )

    _TERNARY_FUN = space.Categorical(
        choices=(interpolate, bias_correct,)
    )

    _CONST = space.Integer(3, 8) # 0-2 are reserved for weights, gradient, and optimizer step
    _VAR = space.Integer(9, AVAILABLE_VARIABLE_SLOTS+9) # And 3-8 are reserved for the constants

    # Is this the right way to handle constants?
    _PARAMS = space.Categorical(
        choices=(
            0, # weights
            1, # gradient
            2, # optimizer step
        )
    )

    _POINTER = space.Categorical(
        choices=(
            space.Resampled(_PARAMS),
            space.Resampled(_CONST),
            space.Resampled(_VAR),
        ),
    )

    _F_ARGS = space.Categorical(
        choices=(
            (
                space.Resampled(_UNARY_FUN),
                space.Resampled(_POINTER),
            ),
            (
                space.Resampled(_BINARY_FUN),
                space.Resampled(_POINTER),
                space.Resampled(_POINTER),
            ),
            (
                space.Resampled(_TERNARY_FUN),
                space.Resampled(_POINTER),
                space.Resampled(_POINTER),
                space.Resampled(_POINTER),
            ),
        ),
    )

    _F = space.Operation(
        operator=_function_writer,
        args=space.Resampled(_F_ARGS),
        kwargs={"store": space.Resampled(_VAR)}, # move to _F_ARGS as normal arg?
    )

    _P_ARGS = space.Categorical(
        choices=(
            (space.Resampled(_F),),
            (space.Resampled(_F), space.Resampled("P"),), # Can be multiple space.Resampled("P")
        ),
    )

    P = space.Operation(
        operator=program_compiler,
        args=space.Resampled(_P_ARGS),
    )

# %%
pipeline = nosBench()

resolved_pipeline, resolution_context = space.resolve(pipeline)

p = resolved_pipeline.P
p_config_string = space.convert_operation_to_string(p)
assert p_config_string 
pretty_config = config_string.ConfigString(p_config_string).pretty_format()
assert pretty_config

# print()
# print("Config string:")
# print(pretty_config)

program = space.convert_operation_to_callable(p)
pprint.pprint(program)

benchmark = nosbench.ToyBenchmark()
fitness = benchmark.query(program, EPOCHS_PER_CONFIG)
print(fitness)
# Out:
# [Instruction(Function(maximum, 2), inputs=[17, 6], output=16),
#  Instruction(Function(mul, 2), inputs=[20, 10], output=15)]
# 1.1031578063964844

# %%
import time

t0 = time.perf_counter()
samples = 10_000

for _ in range(samples):
    resolved_pipeline, resolution_context = space.resolve(pipeline)

t1 = time.perf_counter()

print(f"sampling takes {(t1 - t0) / samples:.2}s on average over {samples} samples")
print(f"duration for {samples} samples: {t1 - t0:.3}s ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 samples = 10_000
#       6 for _ in range(samples):
# ----> 7     resolved_pipeline, resolution_context = space.resolve(pipeline)
#       9 t1 = time.perf_counter()
#      11 print(f"sampling takes {(t1 - t0) / samples:.2}s on average over {samples} samples")
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:1179, in resolve(pipeline, domain_sampler, environment_values)
#    1176     environment_values = {}
#    1178 sampling_resolver = SamplingResolver()
# -> 1179 resolved_pipeline, context = sampling_resolver(
#    1180     obj=pipeline,
#    1181     domain_sampler=domain_sampler,
#    1182     environment_values=environment_values,
#    1183 )
#    1184 return cast(P, resolved_pipeline), context
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:901, in SamplingResolver.__call__(self, obj, domain_sampler, environment_values)
#     890 def __call__(
#     891     self,
#     892     obj: Resolvable,
#     893     domain_sampler: DomainSampler,
#     894     environment_values: Mapping[str, Any],
#     895 ) -> tuple[Resolvable, SamplingResolutionContext]:
#     896     context = SamplingResolutionContext(
#     897         resolution_root=obj,
#     898         domain_sampler=domain_sampler,
#     899         environment_values=environment_values,
#     900     )
# --> 901     return self._resolve(obj, "Resolvable", context), context
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:905, in SamplingResolver._resolve(self, obj, name, context)
#     903 def _resolve(self, obj: Any, name: str, context: SamplingResolutionContext) -> Any:
#     904     with context.resolving(obj, name):
# --> 905         return self._resolver_dispatch(obj, context)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\functools.py:946, in singledispatchmethod.__get__.<locals>._method(*args, **kwargs)
#     944 def _method(*args, **kwargs):
#     945     method = self.dispatcher.dispatch(args[0].__class__)
# --> 946     return method.__get__(obj, cls)(*args, **kwargs)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:935, in SamplingResolver._(self, pipeline_obj, context)
#     932 needed_resolving = False
#     934 for attr_name, initial_attr_value in initial_attrs.items():
# --> 935     resolved_attr_value = self._resolve(initial_attr_value, attr_name, context)
#     936     final_attrs[attr_name] = resolved_attr_value
#     937     needed_resolving = needed_resolving or (initial_attr_value is not resolved_attr_value)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:905, in SamplingResolver._resolve(self, obj, name, context)
#     903 def _resolve(self, obj: Any, name: str, context: SamplingResolutionContext) -> Any:
#     904     with context.resolving(obj, name):
# --> 905         return self._resolver_dispatch(obj, context)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\functools.py:946, in singledispatchmethod.__get__.<locals>._method(*args, **kwargs)
#     944 def _method(*args, **kwargs):
#     945     method = self.dispatcher.dispatch(args[0].__class__)
# --> 946     return method.__get__(obj, cls)(*args, **kwargs)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:1067, in SamplingResolver._(self, operation_obj, context)
#    1064 needed_resolving = False
#    1066 for attr_name, initial_attr_value in initial_attrs.items():
# -> 1067     resolved_attr_value = self._resolve(initial_attr_value, attr_name, context)
#    1068     final_attrs[attr_name] = resolved_attr_value
#    1069     needed_resolving = needed_resolving or (initial_attr_value is not resolved_attr_value)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:905, in SamplingResolver._resolve(self, obj, name, context)
#     903 def _resolve(self, obj: Any, name: str, context: SamplingResolutionContext) -> Any:
#     904     with context.resolving(obj, name):
# --> 905         return self._resolver_dispatch(obj, context)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\functools.py:946, in singledispatchmethod.__get__.<locals>._method(*args, **kwargs)
#     944 def _method(*args, **kwargs):
#     945     method = self.dispatcher.dispatch(args[0].__class__)
# --> 946     return method.__get__(obj, cls)(*args, **kwargs)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:1104, in SamplingResolver._(self, resampled_obj, context)
#    1101 resolvable_to_resample_obj = resampled_obj.from_attrs(initial_attrs)
#    1103 type_name = type(resolvable_to_resample_obj).__name__.lower()
# -> 1104 result = self._resolve(resolvable_to_resample_obj, f"resampled_{type_name}", context)
#    1106 return result
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:905, in SamplingResolver._resolve(self, obj, name, context)
#     903 def _resolve(self, obj: Any, name: str, context: SamplingResolutionContext) -> Any:
#     904     with context.resolving(obj, name):
# --> 905         return self._resolver_dispatch(obj, context)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\functools.py:946, in singledispatchmethod.__get__.<locals>._method(*args, **kwargs)
#     944 def _method(*args, **kwargs):
#     945     method = self.dispatcher.dispatch(args[0].__class__)
# --> 946     return method.__get__(obj, cls)(*args, **kwargs)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:1056, in SamplingResolver._(self, operation_obj, context)
#    1054 operation_obj_first_run = operation_obj
#    1055 if needed_resolving:
# -> 1056     operation_obj_first_run = operation_obj.from_attrs(final_attrs)
#    1058 # Second run.
#    1059 # It is possible the first run was enough,
#    1060 # in this case what we do below won't lead to any changes.
#    1062 initial_attrs = operation_obj_first_run.get_attrs()
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:484, in Operation.from_attrs(self, attrs)
#     482     else:
#     483         final_attrs[name] = value
# --> 484 return type(self)(**final_attrs)
#
# File ~\Git\neps-lum\neps\space\new_space\space.py:431, in Operation.__init__(self, operator, args, kwargs)
#     428 self._operator = operator
#     430 self._args: tuple[Any, ...] | Resolvable
# --> 431 if not isinstance(args, Resolvable):
#     432     self._args = tuple(args) if args else tuple()
#     433 else:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\typing.py:1922, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1920 for attr in cls.__protocol_attrs__:
#    1921     try:
# -> 1922         val = getattr_static(instance, attr)
#    1923     except AttributeError:
#    1924         break
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\inspect.py:1861, in getattr_static(obj, attr, default)
#    1859 if type not in _static_getmro(objtype):
#    1860     klass = objtype
# -> 1861     dict_attr = _shadowed_dict(klass)
#    1862     if (dict_attr is _sentinel or
#    1863         type(dict_attr) is types.MemberDescriptorType):
#    1864         instance_result = _check_instance(obj, attr)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.8-windows-x86_64-none\Lib\inspect.py:1841, in _shadowed_dict(klass)
#    1832 def _shadowed_dict(klass):
#    1833     # gh-118013: the inner function here is decorated with lru_cache for
#    1834     # performance reasons, *but* make sure not to pass strong references
#    (...)   1838     # objects that hold strong references to other objects that take up a
#    1839     # significant amount of memory.
#    1840     return _shadowed_dict_from_weakref_mro_tuple(
# -> 1841         *[make_weakref(entry) for entry in _static_getmro(klass)]
#    1842     )
#
# KeyboardInterrupt:
